# %%
import os

open_ai_key = os.getenv("OPENAI_API_KEY")
if not open_ai_key.startswith('sk-proj'):
            print('No key')
        else:
            print(open_ai_key)
            self.client = OpenAI(api_key=open_ai_key)
            self.model = model
print(open_ai_key)
# Out:
# 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
